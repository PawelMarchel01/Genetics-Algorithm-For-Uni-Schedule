# %%
import pandas as pd
import numpy as np
import heuristic

dane = pd.read_excel('Program.xlsx')

dane=dane.drop('Unnamed: 0', axis=1)

dane['kierownik_przedmiotu']=dane['kierownik_przedmiotu'].fillna(value='Pracownik Dodatkowy')

pattern = dane['realizatorzy_przedmiotu'].iloc[1]
characters_to_remove = "[']"
for iteration in range(len(dane['realizatorzy_przedmiotu'])):
    if dane['realizatorzy_przedmiotu'].iloc[iteration]==pattern:
        dane['realizatorzy_przedmiotu'].iloc[iteration]= dane['kierownik_przedmiotu'].iloc[iteration]
    dane['realizatorzy_przedmiotu'].iloc[iteration] = ''.join([char for char in dane['realizatorzy_przedmiotu'].iloc[iteration] if char not in characters_to_remove])
    dane['realizatorzy_przedmiotu'].iloc[iteration]=dane['realizatorzy_przedmiotu'].iloc[iteration].split('; ')
dane

# %%
test = heuristic(number_pop = 10, dane = dane, cycle_number = 100)

# %%
test.execute()

# %%
wynik = plan(test)

# %%
wynik.list_to_df()

# %%
list(test.ancestors.plan.university.grades.values())[1].class_assignment
# Out:
#                                             Poniedziałek  \
# 8-10   Analiza matematyczna II - C\t Prowadzący: Wojc...
# 10-12                                                NaN
# 12-14                                                NaN
# 14-16                                                NaN
# 16-18                                                NaN
#
#                                                   Wtorek  \
# 8-10                                                 NaN
# 10-12                                                NaN
# 12-14  Komputerowe obliczenia matematyczne - L\t Prow...
# 14-16  Podstawy probabilistyki - W\t Prowadzący: Lesł...
# 16-18  Algebra liniowa z geometrią analityczną II - W...
#
#                                                    Środa  \
# 8-10   Technologie informatyczne II - L\t Prowadzący:...
# 10-12                                                NaN
# 12-14  Algebra liniowa z geometrią analityczną II - C...
# 14-16                                                NaN
# 16-18                                                NaN
#
#                                                 Czwartek  \
# 8-10   Analiza matematyczna II - C\t Prowadzący: Wojc...
# 10-12  Wychowanie fizyczne\t Prowadzący: Sławomira Be...
# 12-14                                                NaN
# 14-16                                                NaN
# 16-18  Topologia przestrzeni metrycznych - C\t Prowad...
#
#                                                   Piątek
# 8-10                                                 NaN
# 10-12  Podstawy probabilistyki - C\t Prowadzący: Fili...
# 12-14  Analiza matematyczna II - W\t Prowadzący: Wojc...
# 14-16  Podstawy ekonomii i przedsiębiorczości - W\t P...
# 16-18  Topologia przestrzeni metrycznych - W\t Prowad...

# %%
wynik.sale[1].class_assignment
# Out:
#        Poniedziałek                                             Wtorek  \
# 8-10            NaN  Podstawy statystyki - L\t Prowadzący: Żywilla ...
# 10-12           NaN                                                NaN
# 12-14           NaN                                                NaN
# 14-16           NaN                                                NaN
# 16-18           NaN                                                NaN
#
#                                                    Środa  \
# 8-10   Programowanie obiektowe w języku Java - L\t Pr...
# 10-12                                                NaN
# 12-14  Komputerowe obliczenia matematyczne - L\t Prow...
# 14-16                                                NaN
# 16-18                                                NaN
#
#                                                 Czwartek  \
# 8-10                                                 NaN
# 10-12                                                NaN
# 12-14                                                NaN
# 14-16  Systemy baz danych - L\t Prowadzący: Pracownik...
# 16-18                                                NaN
#
#                                                   Piątek
# 8-10   Wstęp do obliczeń symbolicznych - L\t Prowadzą...
# 10-12                                                NaN
# 12-14                                                NaN
# 14-16                                                NaN
# 16-18                                                NaN

# %%
test.ancestors.plan.teachers[0].class_assignment
# Out:
#       Poniedziałek                                             Wtorek  \
# 8-10           NaN                                                NaN
# 10-12          NaN                                                NaN
# 12-14          NaN                                                NaN
# 14-16          NaN                                                NaN
# 16-18          NaN  Analiza matematyczna I - C\t Prowadzący: Agnie...
#
#                                                    Środa Czwartek Piątek
# 8-10                                                 NaN      NaN    NaN
# 10-12                                                NaN      NaN    NaN
# 12-14                                                NaN      NaN    NaN
# 14-16                                                NaN      NaN    NaN
# 16-18  Analiza matematyczna I - C\t Prowadzący: Agnie...      NaN    NaN
